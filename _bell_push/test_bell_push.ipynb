# %%
from bell_push import *
import pyzx as zx

h1 = [0, 4, 6]
cnots = [
    (0, 1), (4, 5), (6, 3), (6, 5), (4, 2), (0, 3), (4, 1), (3, 2),
]
c = Circuit.from_list(7, 7, h1, [], cnots)
new_c = c.copy_with_bell_states()
print(new_c.ops)
print(new_c.qubits)
zx.draw(new_c.to_pyzx_circuit())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 9
#       5 cnots = [
#       6     (0, 1), (4, 5), (6, 3), (6, 5), (4, 2), (0, 3), (4, 1), (3, 2),
#       7 ]
#       8 c = Circuit.from_list(7, 7, h1, [], cnots)
# ----> 9 new_c = c.copy_with_bell_states()
#      10 print(new_c.ops)
#      11 print(new_c.qubits)
#
# AttributeError: 'Circuit' object has no attribute 'copy_with_bell_states'

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 c._bell_states()
#
# File ~/PycharmProjects/FT-circuit-synthesis-ZX/boldi-path-cover/bell_push.py:102, in Circuit._bell_states(self)
#     100 qubit = qubits.pop()
#     101 queue = self.qubits[qubit]
# --> 102 a, b = queue[0], queue[1]
#     103 is_bell = False
#     104 if isinstance(a, ZState) and isinstance(b, CNOT):
#
# IndexError: deque index out of range
