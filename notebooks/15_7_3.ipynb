# %%
import stim

c = stim.Circuit("""
R 15
RX 16 17 22
R 23
TICK
CX 16 15 22 3 17 23
RX 18
R 19
TICK
CX 16 19 17 9 18 23
R 20
TICK
CX 16 20 18 10
TICK
CX 20 17 16 22
R 21
TICK
CX 20 8 22 21 18 16
TICK
CX 17 21 22 18 16 1
TICK
CX 21 13 17 2 22 12 18 15
TICK
MX 22
CX 15 14
TICK
R 22
CX 21 15
TICK
CX 18 22 16 21
TICK
CX 15 18 22 17
MX 16
CX 21 11
TICK
CX 15 19 18 6 22 5 17 4
TICK
CX 15 23 19 7
MX 18 22
CX 17 21
TICK
CX 15 0
M 23
MX 19 17
CX 20 21
TICK
MX 15
M 21
MX 20
""")

c.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 2528 1632"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L2496,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L2496,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L2496,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L2496,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L2496,320 " stroke="black"/>
# ...

# %%
c.num_qubits
# Out:
# 24
